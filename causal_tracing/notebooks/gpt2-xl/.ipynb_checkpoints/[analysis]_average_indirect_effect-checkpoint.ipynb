# %%
import torch
import random

import sys
sys.path.append("../../../lib")
import utility

# %%
res = torch.load("../../data/gpt2-xl/indirect_effect_1000_examples.pt")

# %%
num_layers = res[0][1][2]
avg_IE = utility.average_sites(res, num_layers)

# %%
x = num_layers
y = ["first subject token", "middle subject tokens", "last subject token", \
              "first subsequent token", "further tokens", "last token"]
lower_bound = 0
upper_bound = torch.max(avg_IE).item()
incr = (upper_bound - lower_bound) / 10000
title = "AIE"
color_schema = "Purples"

utility.plot_results(avg_IE, x, y, lower_bound, upper_bound, incr, title, color_schema)
